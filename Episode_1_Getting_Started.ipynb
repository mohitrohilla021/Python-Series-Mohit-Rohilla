# %%
print("Python is powering my future!")
# Out:
# Python is powering my future!

# %%
# Project: Personal Assistant That Greets You
name = "Mohan"
print("Hello", name, "! Welcome to your Python journey.")
# Out:
# Hello Mohan ! Welcome to your Python journey.

# %%
# Project: Simple AI Prompt
question = "How many hours should I study daily?"
print("AI Suggestion:", "Study for 2 focused hours with no distractions.")
# Out:
# AI Suggestion: Study for 2 focused hours with no distractions.
